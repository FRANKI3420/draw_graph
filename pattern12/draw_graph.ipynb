# %% [markdown]
# ## 頂点ラベル付きグラフの描画とファイル出力

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors



from matplotlib.backends.backend_pdf import PdfPages



pdf = PdfPages("g.pdf")

# ファイルを読み込む
with open("g.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # 配列を初期化
    color_array = []

    # 指定したサイズの色情報を生成
    for _ in range(max_label+1):
        # ランダムな色情報を生成
        random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
        color_array.append(random_color)

    # 生成した色情報を表示
    print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(10, 10))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()
# Out:
# Color Array: ['#FF0000', '#556B2F', '#6495ED', '#FFFFFF', '#D8BFD8', '#5F9EA0']

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("q.pdf")

# ファイルを読み込む
with open("q.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # 配列を初期化
    color_array = []

    # 指定したサイズの色情報を生成
    for _ in range(max_label+1):
        # ランダムな色情報を生成
        random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
        color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(10, 10))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("gs.pdf")

# ファイルを読み込む
with open("gs.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # # 配列を初期化
    # color_array = []

    # # 指定したサイズの色情報を生成
    # for _ in range(max_label+1):
    #     # ランダムな色情報を生成
    #     random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
    #     color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(13, 13))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 14
#      11 pdf = PdfPages("gs.pdf")
#      13 # ファイルを読み込む
# ---> 14 with open("gs.txt", "r") as f:
#      15     data = f.readlines()
#      17 data_len = len(data)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gs.txt'

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("#827.pdf")

# ファイルを読み込む
with open("#827.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # # 配列を初期化
    # color_array = []

    # # 指定したサイズの色情報を生成
    # for _ in range(max_label+1):
    #     # ランダムな色情報を生成
    #     random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
    #     color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(13, 13))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("#827f.pdf")

# ファイルを読み込む
with open("#827f.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # # 配列を初期化
    # color_array = []

    # # 指定したサイズの色情報を生成
    # for _ in range(max_label+1):
    #     # ランダムな色情報を生成
    #     random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
    #     color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(13, 13))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()
