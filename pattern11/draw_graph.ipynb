# %% [markdown]
# ## 頂点ラベル付きグラフの描画とファイル出力

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors



from matplotlib.backends.backend_pdf import PdfPages



pdf = PdfPages("g.pdf")

# ファイルを読み込む
with open("g.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # 配列を初期化
    color_array = []

    # 指定したサイズの色情報を生成
    for _ in range(max_label+1):
        # ランダムな色情報を生成
        random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
        color_array.append(random_color)

    # 生成した色情報を表示
    print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(10, 10))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()
# Out:
# Color Array: ['#4169E1', '#EE82EE', '#DAA520', '#FF1493', '#2F4F4F', '#008000', '#FFFF00', '#FF4500', '#FF1493', '#9ACD32', '#483D8B', '#B8860B', '#0000CD', '#696969', '#006400', '#00FFFF', '#2F4F4F', '#90EE90', '#C71585', '#F0F8FF', '#00FF00', '#00008B', '#FAEBD7', '#A0522D', '#40E0D0', '#90EE90', '#228B22', '#BDB76B', '#E9967A', '#FF7F50', '#696969', '#00FA9A', '#FFA07A', '#4B0082', '#FFB6C1', '#B8860B', '#FA8072', '#FFB6C1', '#FFEBCD', '#008080', '#FFFF00', '#00BFFF', '#FF00FF', '#008000', '#9370DB', '#FFFFF0', '#D2691E', '#FF8C00', '#D3D3D3', '#FFE4B5', '#0000FF', '#EEE8AA', '#FFDAB9', '#FF00FF', '#F5F5DC']

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("q.pdf")

# ファイルを読み込む
with open("q.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # # 配列を初期化
    # color_array = []

    # # 指定したサイズの色情報を生成
    # for _ in range(max_label+1):
    #     # ランダムな色情報を生成
    #     random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
    #     color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(10, 10))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("gs.pdf")

# ファイルを読み込む
with open("gs.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # # 配列を初期化
    # color_array = []

    # # 指定したサイズの色情報を生成
    # for _ in range(max_label+1):
    #     # ランダムな色情報を生成
    #     random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
    #     color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(13, 13))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("#827.pdf")

# ファイルを読み込む
with open("#827.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # # 配列を初期化
    # color_array = []

    # # 指定したサイズの色情報を生成
    # for _ in range(max_label+1):
    #     # ランダムな色情報を生成
    #     random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
    #     color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(13, 13))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()

# %%
import colorsys
import random
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


from matplotlib.backends.backend_pdf import PdfPages


pdf = PdfPages("#827f.pdf")

# ファイルを読み込む
with open("#827f.txt", "r") as f:
    data = f.readlines()
    
data_len = len(data)

now = 0


while True:
# 頂点数を取得   
    now +=1
    labels = None
    n = int(data[now])
    
    # 頂点IDを取得
    nodes = [int(x) for x in data[now+1:now+1+n]]

    # グラフを初期化
    G = nx.Graph()
    
    id = 0
    countlabels = set()
    max_label = 0

    # 頂点をグラフに追加
    for node in nodes:
        # print(node)
        # G.nodes[id] = node
        G.add_node(id)
        if id==0:
            labels = {id: [id,node]}
        else:
            labels[id] = id,node
        id+=1

        # countlabels.add(node)
        if max_label < node:
            max_label = node
    
    # print(len(countlabels))


    # # 配列を初期化
    # color_array = []

    # # 指定したサイズの色情報を生成
    # for _ in range(max_label+1):
    #     # ランダムな色情報を生成
    #     random_color = random.choice(list(mcolors.CSS4_COLORS.values()))
    #     color_array.append(random_color)

    # # 生成した色情報を表示
    # print("Color Array:", color_array)

    # 辺の数を取得
    m = int(data[now+n+1])
    
    # 辺をグラフに追加
    for line in data[now+n+2:now+n+2+m]:
        u, v = map(int, line.split())
        G.add_edge(u, v)
        
    now+=n+2+m
    
    # fig = plt.figure()

    fig, ax = plt.subplots(figsize=(13, 13))  # 図のサイズを調整


  # force-directed layoutアルゴリズムを使用してノードの位置を計算
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos,node_size=1000,node_color=[color_array[node] for node in nodes])
    # nx.draw_networkx_nodes(G, pos,node_size=1000)

    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos, labels, font_size=12,font_color='black')
    
    plt.show()
    
    plt.close()   # Figureオブジェクトを閉じる
    pdf.savefig(fig)
        
    if now>=data_len:
        break
    
pdf.close()
